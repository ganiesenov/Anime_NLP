# %%
import pandas as pd 
import numpy as np

# %%
# !pip install scrapy
# Out:
# ...
#      ---------------------------------------- 0.0/45.6 kB ? eta -:--:--
#      -------------------------- ------------- 30.7/45.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 45.6/45.6 kB 751.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/311.2 kB ? eta -:--:--
#    ------- -------------------------------- 61.4/311.2 kB 1.7 MB/s eta 0:00:01
#    --------- ------------------------------ 71.7/311.2 kB 1.3 MB/s eta 0:00:01
#    --------------- ---------------------- 122.9/311.2 kB 901.1 kB/s eta 0:00:01
#    -------------------------- ------------- 204.8/311.2 kB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 204.8/311.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  307.2/311.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 311.2/311.2 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/56.5 kB ? eta -:--:--
# ...
